# %%
import pandas as pd

# %%
reviews=pd.read_csv('C:\\Users\\admin\\Downloads\\Fire Stick.csv')

# %%
reviews
# Out:
#                   id      profileName  \
# 0     R3EUSNDMBJK2X2     kushal kumar
# 1     R1WACJL2O37SWG   Ishpreet Singh
# 2     R21CJ1BDI98AH9      Sudharsan A
# 3      R3Q6IHW1DEAMK  Priyank Agrawal
# 4     R3DARG068E5AKX         Suryatej
# ...              ...              ...
# 4995  R29G0GBL9946I1  Srinivasa Rao V
# 4996  R25BE45ZD1FGWZ    Kishan jasani
# 4997   ROL7Y2H1WP5LB        Nagireddy
# 4998  R263CYE5T7SW6N    sumant sharma
# 4999  R2CA4LIG7ZBMU9  Amazon Customer
#
#                                                    text  \
# 0     I am useing Sony bx32 modal tv(2012) it have 2...
# 1     Everything is great but i bought it for 3999/-...
# 2     Product works well upto 1year... Then u need t...
# 3     There is no customer support or details availa...
# 4     In the product description it says 'Made in In...
# ...                                                 ...
# 4995  Ok to use . Led can be used as smart tv. But v...
# ...

# %%
reviews.shape
# Out:
# (5000, 9)

# %%
reviews[reviews['Configuration']!='Fire TV Stick']
#all reviews are about Fire TV Stick only
# Out:
# Empty DataFrame
# Columns: [id, profileName, text, date, title, rating, images, helpful, Configuration]
# Index: []

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             5000 non-null   object
#  1   profileName    5000 non-null   object
#  2   text           4891 non-null   object
#  3   date           5000 non-null   object
#  4   title          5000 non-null   object
#  5   rating         5000 non-null   int64
#  6   images         481 non-null    object
#  7   helpful        5000 non-null   int64
#  8   Configuration  5000 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 351.7+ KB

# %%
reviews.dropna(axis=0,subset=['text'],inplace=True)

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4891 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             4891 non-null   object
#  1   profileName    4891 non-null   object
#  2   text           4891 non-null   object
#  3   date           4891 non-null   object
#  4   title          4891 non-null   object
#  5   rating         4891 non-null   int64
#  6   images         404 non-null    object
#  7   helpful        4891 non-null   int64
#  8   Configuration  4891 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 382.1+ KB

# %%
#duplicates
reviews[reviews.duplicated(subset=['id'])==True]
# Out:
#                   id profileName  \
# 1310  R1R1FRPWMB7P01       Gazan
#
#                                                    text  \
# 1310  I used it for a monitor and it works very well...
#
#                                       date  \
# 1310  Reviewed in India on 1 February 2022
#
#                                            title  rating images  helpful  \
# 1310  Does the job it is meant for…. beautifully       5    NaN        0
#
#       Configuration
# 1310  Fire TV Stick

# %%
reviews[reviews['id']=='R1R1FRPWMB7P01']
# Out:
#                   id profileName  \
# 1309  R1R1FRPWMB7P01       Gazan
# 1310  R1R1FRPWMB7P01       Gazan
#
#                                                    text  \
# 1309  I used it for a monitor and it works very well...
# 1310  I used it for a monitor and it works very well...
#
#                                       date  \
# 1309  Reviewed in India on 1 February 2022
# 1310  Reviewed in India on 1 February 2022
#
#                                            title  rating images  helpful  \
# 1309  Does the job it is meant for…. beautifully       5    NaN        0
# 1310  Does the job it is meant for…. beautifully       5    NaN        0
#
#       Configuration
# 1309  Fire TV Stick
# 1310  Fire TV Stick

# %%
reviews=reviews.drop_duplicates(subset=['id'],keep='first')

# %%
reviews
# Out:
#                   id      profileName  \
# 0     R3EUSNDMBJK2X2     kushal kumar
# 1     R1WACJL2O37SWG   Ishpreet Singh
# 2     R21CJ1BDI98AH9      Sudharsan A
# 3      R3Q6IHW1DEAMK  Priyank Agrawal
# 4     R3DARG068E5AKX         Suryatej
# ...              ...              ...
# 4995  R29G0GBL9946I1  Srinivasa Rao V
# 4996  R25BE45ZD1FGWZ    Kishan jasani
# 4997   ROL7Y2H1WP5LB        Nagireddy
# 4998  R263CYE5T7SW6N    sumant sharma
# 4999  R2CA4LIG7ZBMU9  Amazon Customer
#
#                                                    text  \
# 0     I am useing Sony bx32 modal tv(2012) it have 2...
# 1     Everything is great but i bought it for 3999/-...
# 2     Product works well upto 1year... Then u need t...
# 3     There is no customer support or details availa...
# 4     In the product description it says 'Made in In...
# ...                                                 ...
# 4995  Ok to use . Led can be used as smart tv. But v...
# ...

# %% [markdown]
# ### EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='rating',data=reviews)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
reviews.shape
# Out:
# (4890, 9)

# %%
reviews
# Out:
#                   id      profileName  \
# 0     R3EUSNDMBJK2X2     kushal kumar
# 1     R1WACJL2O37SWG   Ishpreet Singh
# 2     R21CJ1BDI98AH9      Sudharsan A
# 3      R3Q6IHW1DEAMK  Priyank Agrawal
# 4     R3DARG068E5AKX         Suryatej
# ...              ...              ...
# 4995  R29G0GBL9946I1  Srinivasa Rao V
# 4996  R25BE45ZD1FGWZ    Kishan jasani
# 4997   ROL7Y2H1WP5LB        Nagireddy
# 4998  R263CYE5T7SW6N    sumant sharma
# 4999  R2CA4LIG7ZBMU9  Amazon Customer
#
#                                                    text  \
# 0     I am useing Sony bx32 modal tv(2012) it have 2...
# 1     Everything is great but i bought it for 3999/-...
# 2     Product works well upto 1year... Then u need t...
# 3     There is no customer support or details availa...
# 4     In the product description it says 'Made in In...
# ...                                                 ...
# 4995  Ok to use . Led can be used as smart tv. But v...
# ...

# %%
reviews['count']=[len(sentence.split()) for sentence in reviews.text.values ]
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1020\651724000.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['count']=[len(sentence.split()) for sentence in reviews.text.values ]

# %%
reviews
# Out:
#                   id      profileName  \
# 0     R3EUSNDMBJK2X2     kushal kumar
# 1     R1WACJL2O37SWG   Ishpreet Singh
# 2     R21CJ1BDI98AH9      Sudharsan A
# 3      R3Q6IHW1DEAMK  Priyank Agrawal
# 4     R3DARG068E5AKX         Suryatej
# ...              ...              ...
# 4995  R29G0GBL9946I1  Srinivasa Rao V
# 4996  R25BE45ZD1FGWZ    Kishan jasani
# 4997   ROL7Y2H1WP5LB        Nagireddy
# 4998  R263CYE5T7SW6N    sumant sharma
# 4999  R2CA4LIG7ZBMU9  Amazon Customer
#
#                                                    text  \
# 0     I am useing Sony bx32 modal tv(2012) it have 2...
# 1     Everything is great but i bought it for 3999/-...
# 2     Product works well upto 1year... Then u need t...
# 3     There is no customer support or details availa...
# 4     In the product description it says 'Made in In...
# ...                                                 ...
# 4995  Ok to use . Led can be used as smart tv. But v...
# ...

# %%
sns.distplot(reviews['count'])
# Out:
# C:\Users\admin\anaconda3.2\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='count', ylabel='Density'>

# %% [markdown]
# ###  TEXT PREPROCESSING

# %%
from tqdm import tqdm
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
stemmer=SnowballStemmer(language='english')
from nltk.stem.wordnet import WordNetLemmatizer
from bs4 import BeautifulSoup
import re
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
comments=reviews['text']

# %%
comments[0]
# Out:
# "I am useing Sony bx32 modal tv(2012) it have 2 HDMI Port . But fire tv stick is not supporting to my tv, not working properly & getting display issues. so don't buy for Sony TV's"

# %%
def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)
    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# %%
preprocessed_reviews=[]
for sentence in tqdm(comments):
    #removing http links
    sentence=re.sub(r"http\S+"," ",sentence)
    #removing special tags
    sentence=BeautifulSoup(sentence,'lxml').get_text()
    #decontracing the words
    sentence=decontracted(sentence)
    #removing words with numbers
    sentence=re.sub("\S*\d\S*",' ',sentence)
    #removing special characters
    sentence=re.sub("[^A-Za-z0-9]+",' ',sentence)
    #removing numbers
    sentence=re.sub("\d+",' ',sentence)
    #removing stopwords & stemming
    sentence=' '.join(stemmer.stem(word.lower()) for word in sentence.split() if word not in stopwords.words('english'))
    preprocessed_reviews.append(sentence.strip())
# Out:
#   0%|                                                                                 | 1/4890 [00:00<30:17,  2.69it/s]C:\Users\admin\anaconda3.2\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████| 4890/4890 [00:55<00:00, 87.32it/s]

# %%
preprocessed_reviews[0]
# Out:
# 'i use soni modal hdmi port but fire tv stick support tv work proper get display issu buy soni tv'

# %%
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer,TfidfVectorizer
import string

# %%
len(preprocessed_reviews)
# Out:
# 4890

# %% [markdown]
# ### BOW

# %%
bow=CountVectorizer().fit(preprocessed_reviews)
print(bow.get_feature_names()[:15])
bow_transformer=bow.transform(preprocessed_reviews)
# Out:
# ['aa', 'aaa', 'aaaa', 'aacha', 'aaj', 'aap', 'aapk', 'aat', 'abhi', 'abhishek', 'abil', 'abl', 'abnorm', 'about', 'abox']
# C:\Users\admin\anaconda3.2\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
message=preprocessed_reviews[0]

# %%
msg_bow=bow.transform([message])

# %%
print(msg_bow)
print(bow.get_feature_names()[3200])
print(bow.get_feature_names()[3609])
# Out:
#   (0, 508)	1
#   (0, 517)	1
#   (0, 958)	1
#   (0, 1276)	1
#   (0, 1409)	1
#   (0, 1534)	1
#   (0, 1784)	1
#   (0, 2152)	1
#   (0, 2581)	1
#   (0, 2694)	1
#   (0, 3200)	2
#   (0, 3283)	1
#   (0, 3389)	1
#   (0, 3609)	3
#   (0, 3719)	1
#   (0, 3911)	1
# soni
# tv

# %%
print(bow_transformer.shape)
print(bow_transformer[0])
print(bow.get_feature_names()[3609])
# Out:
# (4890, 3989)
#   (0, 508)	1
#   (0, 517)	1
#   (0, 958)	1
#   (0, 1276)	1
#   (0, 1409)	1
#   (0, 1534)	1
#   (0, 1784)	1
#   (0, 2152)	1
#   (0, 2581)	1
#   (0, 2694)	1
#   (0, 3200)	2
#   (0, 3283)	1
#   (0, 3389)	1
#   (0, 3609)	3
#   (0, 3719)	1
#   (0, 3911)	1
# tv

# %% [markdown]
# ### TF-IDF TRANSFORMER

# %%
transformer=TfidfTransformer().fit(bow_transformer)

# %%
tfidf=transformer.transform(bow_transformer)

# %%
msg_tf=transformer.transform(msg_bow)

# %%
print(msg_tf)
print(transformer.idf_[bow.vocabulary_['soni']])
# Out:
#   (0, 3911)	0.11954429359689821
#   (0, 3719)	0.14676663671412274
#   (0, 3609)	0.34921944023629126
#   (0, 3389)	0.20792788753755512
#   (0, 3283)	0.14093931626074802
#   (0, 3200)	0.4421469376600835
#   (0, 2694)	0.22281924131606046
#   (0, 2581)	0.2630292493627336
#   (0, 2152)	0.39491627030440685
#   (0, 1784)	0.20042046617207376
#   (0, 1534)	0.23766650342662732
#   (0, 1409)	0.19294511714067156
#   (0, 1276)	0.14805132134686602
#   (0, 958)	0.28400916895686673
#   (0, 517)	0.16872589926657836
#   (0, 508)	0.2095248121616147
# 4.539325002938096

# %% [markdown]
# ### n-grams

# %% [markdown]
# count_vec_ngram=CountVectorizer(ngram_range=(1,2),min_df=10)
# count_vec_ngram.fit(preprocessed_reviews)
# print(count_vec_ngram.get_feature_names()[:15])
# final_ngrams_count=count_vec_ngram.transform(preprocessed_reviews)

# %% [markdown]
# print(final_ngrams_count.shape)

# %% [markdown]
# ### TF-IDF VECTORIZER

# %%
tfidf_vectorizer=TfidfVectorizer()

# %%
tfidf_vectorizer.fit(preprocessed_reviews)
# Out:
# TfidfVectorizer()

# %%
tfidf_vectorizer.get_feature_names()[:15]
# Out:
# ['aa',
#  'aaa',
#  'aaaa',
#  'aacha',
#  'aaj',
#  'aap',
#  'aapk',
#  'aat',
#  'abhi',
#  'abhishek',
#  'abil',
#  'abl',
#  'abnorm',
#  'about',
#  'abox']

# %%
final_tfidf=tfidf_vectorizer.transform(preprocessed_reviews)

# %%
print(final_tfidf.shape)
print(final_tfidf[0])
# Out:
# (4890, 3989)
#   (0, 3911)	0.11954429359689821
#   (0, 3719)	0.14676663671412274
#   (0, 3609)	0.34921944023629126
#   (0, 3389)	0.20792788753755512
#   (0, 3283)	0.14093931626074802
#   (0, 3200)	0.4421469376600835
#   (0, 2694)	0.22281924131606046
#   (0, 2581)	0.2630292493627336
#   (0, 2152)	0.39491627030440685
#   (0, 1784)	0.20042046617207376
#   (0, 1534)	0.23766650342662732
#   (0, 1409)	0.19294511714067156
#   (0, 1276)	0.14805132134686602
#   (0, 958)	0.28400916895686673
#   (0, 517)	0.16872589926657836
#   (0, 508)	0.2095248121616147

# %% [markdown]
# ### sentiment analysis

# %%
preprocessed_reviews
# Out:
# ['i use soni modal hdmi port but fire tv stick support tv work proper get display issu buy soni tv',
#  'everyth great bought day price hurt alot rs loss be prime custom unhappi massiv price drop',
#  'product work well upto then u need buy new one no choic i bought product rs offer year remot stop work put new batteri dri day i want buy new remot new remot cost rs it cheat other brand like mi give cheaper remot',
#  'there custom support detail avail tvs compat and guess return well got buck wast i bought watch mani posit review feel sad',
#  'in product descript say made india packag box say china this mislead',
#  'the system ui interfac total chang grey icon miss icon side load app see all tab missingupd fix anyth i thought i got defect product tri replacingbut amazon respondi use friend fire stick i know firestick issu almost use month face problem henc i proceed buy one i disappoint got defect product softwaremor disappoint thing i even replac wow',
# ...

# %%
len(preprocessed_reviews)
# Out:
# 4890

# %%
table=pd.DataFrame(columns=['sentence'],data=preprocessed_reviews)

# %%
table
# Out:
#                                                sentence
# 0     i use soni modal hdmi port but fire tv stick s...
# 1     everyth great bought day price hurt alot rs lo...
# 2     product work well upto then u need buy new one...
# 3     there custom support detail avail tvs compat a...
# 4     in product descript say made india packag box ...
# ...                                                 ...
# 4885  ok use led use smart tv but voic recognit appr...
# 4886  best streamgood content alsoi person like prod...
# 4887  i gift relat like soo much pictur qualiti oper...
# 4888  awesom usual this third fire stick oldest stil...
# 4889  the most reliabl stream devic i ever come acro...
#
# [4890 rows x 1 columns]

# %%
from afinn import Afinn
from textblob import TextBlob

# %%
affin=Afinn()

# %%
afinn_score=[]
for sentence in preprocessed_reviews:
    afinn_score.append(affin.score(sentence))
afinn_sentiment=[]
for value in afinn_score:
    if value>0:
        afinn_sentiment.append('positive')
    elif value<0:
        afinn_sentiment.append('negative')
    else:
        afinn_sentiment.append('neutral')

# %%
table['afinn_score']=afinn_score
table['afinn_sent']=afinn_sentiment

# %%
table
# Out:
#                                                sentence  afinn_score  \
# 0     i use soni modal hdmi port but fire tv stick s...          0.0
# 1     everyth great bought day price hurt alot rs lo...         -3.0
# 2     product work well upto then u need buy new one...         -2.0
# 3     there custom support detail avail tvs compat a...          0.0
# 4     in product descript say made india packag box ...         -3.0
# ...                                                 ...          ...
# 4885  ok use led use smart tv but voic recognit appr...          1.0
# 4886  best streamgood content alsoi person like prod...          8.0
# 4887  i gift relat like soo much pictur qualiti oper...          7.0
# 4888  awesom usual this third fire stick oldest stil...         -2.0
# 4889  the most reliabl stream devic i ever come acro...          6.0
#
#      afinn_sent
# 0       neutral
# 1      negative
# 2      negative
# 3       neutral
# 4      negative
# ...         ...
# ...

# %%
polarity=TextBlob(preprocessed_reviews[0]).sentiment.polarity

# %%
polarity=[]
for sentence in preprocessed_reviews:
    polarity.append(TextBlob(sentence).sentiment.polarity)
textblob_sentiment=[]
for value in polarity:
    if value>0:
        textblob_sentiment.append('positive')
    elif value<0:
        textblob_sentiment.append('negative')
    else:
        textblob_sentiment.append('neutral')

# %%
table['textblob_polarity']=polarity
table['textblob_sentiment']=textblob_sentiment

# %%
table.describe()
# Out:
#        afinn_score  textblob_polarity
# count  4890.000000        4890.000000
# mean      2.014315           0.290591
# std       3.417526           0.343381
# min     -13.000000          -1.000000
# 25%       0.000000           0.000000
# 50%       2.000000           0.262760
# 75%       3.000000           0.600000
# max      29.000000           1.000000

# %%
table['rating']=reviews['rating']

# %%
label=[]
for i in table['afinn_score']:
    if i>0:
        label.append(1)
    elif i<0:
        label.append(-1)
    else:
        label.append(0)
table['label']=label

# %%
table
# Out:
#                                                sentence  afinn_score  \
# 0     i use soni modal hdmi port but fire tv stick s...          0.0
# 1     everyth great bought day price hurt alot rs lo...         -3.0
# 2     product work well upto then u need buy new one...         -2.0
# 3     there custom support detail avail tvs compat a...          0.0
# 4     in product descript say made india packag box ...         -3.0
# ...                                                 ...          ...
# 4885  ok use led use smart tv but voic recognit appr...          1.0
# 4886  best streamgood content alsoi person like prod...          8.0
# 4887  i gift relat like soo much pictur qualiti oper...          7.0
# 4888  awesom usual this third fire stick oldest stil...         -2.0
# 4889  the most reliabl stream devic i ever come acro...          6.0
#
#      afinn_sent  textblob_polarity textblob_sentiment  rating  label
# 0       neutral           0.000000            neutral     1.0      0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
import string
import shap
import spacy
import eli5
import pickle
from nltk.stem.porter import PorterStemmer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import classification_report,accuracy_score,roc_auc_score,confusion_matrix
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import WordPunctTokenizer
warnings.simplefilter('ignore')
sns.set(style="white", palette="muted", color_codes=True)
spacy_nlp = spacy.load('en_core_web_sm')
shap.initjs()
outputdir = 'Model_Ouput'
if not os.path.exists(outputdir):
    os.makedirs(outputdir)
# Out:
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# ...

# %%
reviews = table['sentence']
feedback = table['label']

# %%
# Termite will help us know, which words provide an import to category
category = list(feedback.unique())
vectorizer = TfidfVectorizer()
vectorizer.fit(table['sentence']) #Fitting TFIDF vectorizer on dataset

mat_tfidf_cat0 = vectorizer.transform(table[feedback==category[0]]['sentence']) # creating a matrix
category0_score = mat_tfidf_cat0.sum(axis=0) # taking sum of the matrix for all rows
category0_words_frequency = [(word, category0_score[0, idx]) for word, idx in vectorizer.vocabulary_.items()] # form a list all tuple with (words, score) 
df_cat0 = pd.DataFrame(list(sorted(category0_words_frequency, key = lambda x: x[1], reverse=True)),columns=['feature','Positive']) #Sort and form a dataframe
df_cat0 = df_cat0.head(10) # take top 10 row

mat_tfidf_cat1 = vectorizer.transform(table[feedback==category[1]]['sentence'])
category0_score = mat_tfidf_cat1.sum(axis=0)
category0_words_frequency = [(word, category0_score[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
df_cat1 = pd.DataFrame(list(sorted(category0_words_frequency, key = lambda x: x[1], reverse=True)),columns=['feature','Negative'])
df_cat1 = df_cat1.head(10)

df_categories = pd.merge(df_cat0,df_cat1,how='outer') #join two dataframes
df_categories.fillna(0,inplace=True) #Fill all nan with 0
df_categories.set_index('feature',inplace=True) # set all words as index
df_categories_norm = (df_categories)/(df_categories.max()-df_categories.min()) # standard normalization

# %%
import numpy as np
from textacy.viz.termite import draw_termite_plot
draw_termite_plot(np.array(df_categories_norm.values),df_categories_norm.columns,df_categories_norm.index,highlight_cols=[0,1])
plt.show()

# %%
xtrain,xtest,ytrain,ytest = train_test_split(reviews,feedback,test_size=0.2,random_state=45) #splitting dataset with test size as 20%

# %%
#Creating dataset for Bag of word model
countvect = CountVectorizer()


review_train_vectorize = countvect.fit_transform(xtrain)
review_test_vectorize = countvect.transform(xtest)

#Creating dataset for TFIDF model
tfidf_transform = TfidfTransformer()

review_train_tfidf = tfidf_transform.fit_transform(review_train_vectorize)
review_test_tfidf = tfidf_transform.transform(review_test_vectorize)

# %%
tfidf_transform = TfidfTransformer()
with open(outputdir+'/trasform.pkl','wb') as file:
    pickle.dump(nb,file)

# %%
import streamlit as st
import pickle
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import re

# %%
ps = PorterStemmer()

# %%
text = "Nice Product"

# %%
def text_processing(text):
    text = re.sub('[^a-zA-Z]', ' ', text)
    text = text.lower()
    text = text.split()
    # text = [ps.stem(word) for word in text if not word in stopwords.words('english')]
    text = [ps.stem(word) for word in text]
    text = ' '.join(text)
    return text

# %%
 transformed_review = text_processing(text)

# %%
tf=TfidfVectorizer(max_features=3000)

# %%
vector_ip = tf.transform(transformed_review)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Input In [91], in <cell line: 1>()
# ----> 1 vector_ip = tf.transform(transformed_review)
#
# File ~\anaconda3.2\lib\site-packages\sklearn\feature_extraction\text.py:2099, in TfidfVectorizer.transform(self, raw_documents)
#    2083 def transform(self, raw_documents):
#    2084     """Transform documents to document-term matrix.
#    2085
#    2086     Uses the vocabulary and document frequencies (df) learned by fit (or
#    (...)
#    2097         Tf-idf-weighted document-term matrix.
#    2098     """
# -> 2099     check_is_fitted(self, msg="The TF-IDF vectorizer is not fitted")
#    2101     X = super().transform(raw_documents)
#    2102     return self._tfidf.transform(X, copy=False)
#
# File ~\anaconda3.2\lib\site-packages\sklearn\utils\validation.py:1222, in check_is_fitted(estimator, attributes, msg, all_or_any)
# ...

# %%
category = list(feedback.unique())
vectorizer = TfidfVectorizer()
vectorizer.fit(table['sentence'])
with open(outputdir+'/trasform.pkl','wb') as file:
    pickle.dump(nb,file)

# %% [markdown]
# # Machine Learning Model Building

# %% [markdown]
# # Naive Bayes

# %%
#Bow model
nb = MultinomialNB()
nb.fit(review_train_vectorize,ytrain)
y_pred_vect = nb.predict(review_test_vectorize)
print(classification_report(ytest,y_pred_vect))
print(f'Accuracy Score:{accuracy_score(ytest,y_pred_vect)}')


with open(outputdir+'/naive_bayes_bow.pkl','wb') as file:
    pickle.dump(nb,file)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.72      0.61      0.66       133
#            0       0.86      0.35      0.49       262
#            1       0.74      0.96      0.84       583
#
#     accuracy                           0.75       978
#    macro avg       0.77      0.64      0.66       978
# weighted avg       0.77      0.75      0.72       978
#
# Accuracy Score:0.7494887525562373

# %%
#TFIDF model
nb.fit(review_train_tfidf,ytrain)
ypred_nb_tfidf = nb.predict(review_test_tfidf)
print(classification_report(ytest,ypred_nb_tfidf))
print(f'Accuracy Score:{accuracy_score(ytest,ypred_nb_tfidf)}')


with open(outputdir+'/naive_bayes_tfidf.pkl','wb') as file:
    pickle.dump(nb,file)
# Out:
#               precision    recall  f1-score   support
#
#           -1       1.00      0.09      0.17       133
#            0       0.84      0.16      0.27       262
#            1       0.64      1.00      0.78       583
#
#     accuracy                           0.65       978
#    macro avg       0.83      0.42      0.41       978
# weighted avg       0.74      0.65      0.56       978
#
# Accuracy Score:0.6513292433537833

# %% [markdown]
# # SVM

# %%
#Bow model
svm = SVC(kernel='linear')
svm.fit(review_train_vectorize,ytrain)
ypred_vect_svm = svm.predict(review_test_vectorize)
print(classification_report(ytest,ypred_vect_svm))
print(f'Accuracy Score:{accuracy_score(ytest,ypred_vect_svm)}')


with open(outputdir+'/svm_bow.pkl','wb') as file:
    pickle.dump(nb,file)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.86      0.85      0.85       133
#            0       0.91      0.90      0.90       262
#            1       0.96      0.97      0.97       583
#
#     accuracy                           0.93       978
#    macro avg       0.91      0.91      0.91       978
# weighted avg       0.93      0.93      0.93       978
#
# Accuracy Score:0.9335378323108384

# %%
#TFIDF model
svm.fit(review_train_tfidf,ytrain)
ypred_tfidf_svm = svm.predict(review_test_tfidf)
print(classification_report(ytest,ypred_tfidf_svm))
print(f'Accuracy Score:{accuracy_score(ytest,ypred_tfidf_svm)}')


with open(outputdir+'/svm_tfidf.pkl','wb') as file:
    pickle.dump(nb,file)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.87      0.77      0.82       133
#            0       0.89      0.85      0.87       262
#            1       0.93      0.97      0.95       583
#
#     accuracy                           0.91       978
#    macro avg       0.90      0.86      0.88       978
# weighted avg       0.91      0.91      0.91       978
#
# Accuracy Score:0.9130879345603272

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier,ExtraTreeClassifier

# %%
#Bow model
dt = DecisionTreeClassifier()
dt.fit(review_train_vectorize,ytrain)
ypred_vect_dt = dt.predict(review_test_vectorize)
print(classification_report(ytest,ypred_vect_dt))
print(f'Accuracy Score:{accuracy_score(ytest,ypred_vect_dt)}')


with open(outputdir+'/dt_bow.pkl','wb') as file:
    pickle.dump(nb,file)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.76      0.74      0.75       133
#            0       0.91      0.91      0.91       262
#            1       0.94      0.95      0.95       583
#
#     accuracy                           0.91       978
#    macro avg       0.87      0.86      0.87       978
# weighted avg       0.91      0.91      0.91       978
#
# Accuracy Score:0.908997955010225

# %%
#TFIDF model
dt.fit(review_train_tfidf,ytrain)
ypred_tfidf_dt = dt.predict(review_test_tfidf)
print(classification_report(ytest,ypred_tfidf_dt))
print(f'Accuracy Score:{accuracy_score(ytest,ypred_tfidf_dt)}')


with open(outputdir+'/dt_tfidf.pkl','wb') as file:
    pickle.dump(nb,file)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.76      0.74      0.75       133
#            0       0.90      0.90      0.90       262
#            1       0.94      0.94      0.94       583
#
#     accuracy                           0.90       978
#    macro avg       0.86      0.86      0.86       978
# weighted avg       0.90      0.90      0.90       978
#
# Accuracy Score:0.9028629856850716

# %% [markdown]
# # Interpret Model

# %% [markdown]
# # Feature Importance

# %%
explainer = shap.LinearExplainer(nb,review_train_vectorize,feature_dependence='independent')
shap_values = explainer.shap_values(review_test_vectorize)
review_test_vectorize_array = review_test_vectorize.toarray()
shap.summary_plot(shap_values,review_test_vectorize_array,feature_names=countvect.get_feature_names(),plot_type='bar',layered_violin_max_num_bins=20)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
import streamlit as st
import pickle
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import re




tf = pickle.load(open('C://Users//admin//Downloads//Model_Ouput//tokenizing_text (1).pkl', 'rb'))
model = pickle.load(open('C://Users//admin//Downloads//Model_Ouput//svm_bow.pkl', 'rb'))

ps = PorterStemmer()


def text_processing(text):
    text = re.sub('[^a-zA-Z]', ' ', text)
    text = text.lower()
    text = text.split()
    # text = [ps.stem(word) for word in text if not word in stopwords.words('english')]
    text = [ps.stem(word) for word in text]
    text = ' '.join(text)
    return text


st.title('Review Classification')

review_title=st.text_input("Enter the review title")

review = st.text_area('Enter the review')

review=review_title+' '+review

if st.button('Predict'):

    transformed_review = text_processing(review)

    # vectorize
    vector_ip = tf.transform([transformed_review])

    # predict
    res = model.predict(vector_ip)[0]
    m_prob = model.predict_proba(vector_ip)
    # Display

    if res == 1:
        st.success('The Review is positive' + ' ' + '(' + str(np.round(m_prob[0][1], 2)) + ')')
    else:
        st.error('The review is negative' + ' ' + '(' + str(np.round(m_prob[0][0], 2)) + ')')
